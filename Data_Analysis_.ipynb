# %% [markdown]
# **Pandas** **Library**

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Chocolate.csv")

# %%
df
# Out:
#           Sales Person    Country              Product        Date  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022
# 1          Van Tuxwell      India        85% Dark Bars  01/08/2022
# 2         Gigi Bohling      India  Peanut Butter Cubes  07/07/2022
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022
# ...                ...        ...                  ...         ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims  17/05/2024
# 3278    Jehu Rudeforth        USA           White Choc  07/06/2024
# 3279      Ches Bonnell     Canada  Organic Choco Syrup  26/07/2024
# 3280    Dotty Strutley      India              Eclairs  28/07/2024
# 3281  Karlen McCaffrey      India       70% Dark Bites  23/05/2024
#
#           Amount  Boxes Shipped
# 0      $5,320.00            180
# 1      $7,896.00             94
# 2      $4,501.00             91
# ...

# %%
df.describe()
# Out:
#        Boxes Shipped
# count    3282.000000
# mean      164.666971
# std       124.024736
# min         1.000000
# 25%        71.000000
# 50%       137.000000
# 75%       232.000000
# max       778.000000

# %%
df.count()
# Out:
# Sales Person     3282
# Country          3282
# Product          3282
# Date             3282
# Amount           3282
# Boxes Shipped    3282
# dtype: int64

# %%
print(df)
# Out:
#           Sales Person    Country              Product        Date  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022
# 1          Van Tuxwell      India        85% Dark Bars  01/08/2022
# 2         Gigi Bohling      India  Peanut Butter Cubes  07/07/2022
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022
# ...                ...        ...                  ...         ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims  17/05/2024
# 3278    Jehu Rudeforth        USA           White Choc  07/06/2024
# 3279      Ches Bonnell     Canada  Organic Choco Syrup  26/07/2024
# 3280    Dotty Strutley      India              Eclairs  28/07/2024
# 3281  Karlen McCaffrey      India       70% Dark Bites  23/05/2024
#
#           Amount  Boxes Shipped
# 0      $5,320.00            180
# 1      $7,896.00             94
# 2      $4,501.00             91
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#       Sales Person      Country              Product        Date      Amount  \
# 0   Jehu Rudeforth           UK      Mint Chip Choco  04/01/2022   $5,320.00
# 1      Van Tuxwell        India        85% Dark Bars  01/08/2022   $7,896.00
# 2     Gigi Bohling        India  Peanut Butter Cubes  07/07/2022   $4,501.00
# 3     Jan Morforth    Australia  Peanut Butter Cubes  27/04/2022  $12,726.00
# 4   Jehu Rudeforth           UK  Peanut Butter Cubes  24/02/2022  $13,685.00
# 5      Van Tuxwell        India   Smooth Sliky Salty  06/06/2022   $5,376.00
# 6       Oby Sorrel           UK      99% Dark & Pure  25/01/2022  $13,685.00
# 7  Gunar Cockshoot    Australia          After Nines  24/03/2022   $3,080.00
# 8   Jehu Rudeforth  New Zealand       50% Dark Bites  20/04/2022   $3,990.00
# 9      Brien Boise    Australia      99% Dark & Pure  04/07/2022   $2,835.00
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184
# ...

# %%
df.tail(10)
# Out:
#              Sales Person      Country              Product        Date  \
# 3272      Roddy Speechley        India       50% Dark Bites  14/03/2024
# 3273         Barr Faughny  New Zealand      99% Dark & Pure  24/05/2024
# 3274  Dennison Crosswaite       Canada  Organic Choco Syrup  28/01/2024
# 3275       Beverie Moffet        India         Almond Choco  24/05/2024
# 3276          Brien Boise    Australia  Peanut Butter Cubes  19/08/2024
# 3277     Karlen McCaffrey    Australia  Spicy Special Slims  17/05/2024
# 3278       Jehu Rudeforth          USA           White Choc  07/06/2024
# 3279         Ches Bonnell       Canada  Organic Choco Syrup  26/07/2024
# 3280       Dotty Strutley        India              Eclairs  28/07/2024
# 3281     Karlen McCaffrey        India       70% Dark Bites  23/05/2024
#
#          Amount  Boxes Shipped
# 3272  $9,976.22             12
# 3273  $9,152.72            208
# 3274  $9,251.37             79
# 3275  $3,634.26            100
# ...

# %%
df.describe()
# Out:
#        Boxes Shipped
# count    3282.000000
# mean      164.666971
# std       124.024736
# min         1.000000
# 25%        71.000000
# 50%       137.000000
# 75%       232.000000
# max       778.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   3282 non-null   object
#  1   Country        3282 non-null   object
#  2   Product        3282 non-null   object
#  3   Date           3282 non-null   object
#  4   Amount         3282 non-null   object
#  5   Boxes Shipped  3282 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 154.0+ KB

# %%
df['Country']
# Out:
# 0              UK
# 1           India
# 2           India
# 3       Australia
# 4              UK
#           ...
# 3277    Australia
# 3278          USA
# 3279       Canada
# 3280        India
# 3281        India
# Name: Country, Length: 3282, dtype: object

# %%
data=df['Country']

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
df.loc[23 :]
# Out:
#           Sales Person    Country              Product        Date     Amount  \
# 23        Husein Augar         UK        Drinking Coco  14/03/2022  $3,003.00
# 24         Kaine Padly  Australia              Eclairs  28/02/2022  $7,672.00
# 25    Karlen McCaffrey      India     Fruit & Nut Bars  26/01/2022    $168.00
# 26     Roddy Speechley     Canada  Spicy Special Slims  09/02/2022  $1,652.00
# 27        Husein Augar        USA              Eclairs  07/07/2022  $4,025.00
# ...                ...        ...                  ...         ...        ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims  17/05/2024  $5,303.58
# 3278    Jehu Rudeforth        USA           White Choc  07/06/2024  $7,339.32
# 3279      Ches Bonnell     Canada  Organic Choco Syrup  26/07/2024    $616.09
# 3280    Dotty Strutley      India              Eclairs  28/07/2024  $2,504.62
# 3281  Karlen McCaffrey      India       70% Dark Bites  23/05/2024  $5,915.87
#
#       Boxes Shipped
# ...

# %%
df.loc[23:24]
# Out:
#     Sales Person    Country        Product        Date     Amount  \
# 23  Husein Augar         UK  Drinking Coco  14/03/2022  $3,003.00
# 24   Kaine Padly  Australia        Eclairs  28/02/2022  $7,672.00
#
#     Boxes Shipped
# 23            113
# 24            115

# %%
df.loc[23:23]
# Out:
#     Sales Person Country        Product        Date     Amount  Boxes Shipped
# 23  Husein Augar      UK  Drinking Coco  14/03/2022  $3,003.00            113

# %%
filter_df = df[df['Country']=='India'].count()

# %%
filter_df
# Out:
# Sales Person     552
# Country          552
# Product          552
# Date             552
# Amount           552
# Boxes Shipped    552
# dtype: int64
