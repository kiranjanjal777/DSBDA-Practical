# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from  sklearn.model_selection import train_test_split

# %%
from  sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("/content/appliance_energy.csv")

# %%
df.tail(5)
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374

# %%
print(df.isnull().sum())
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
df=df.dropna()

# %%
#Independent varaiblee
X=df[['Temperature (°C)']]
#Dependent varaible
Y=df['Energy Consumption (kWh)']

# %%
print(X,Y)
# Out:
#     Temperature (°C)
# 0          22.490802
# 1          34.014286
# 2          29.639879
# 3          26.973170
# 4          18.120373
# ..               ...
# 95         24.875912
# 96         25.454657
# 97         23.550820
# 98         15.508383
# 99         17.157829
#
# [100 rows x 1 columns] 0     2.292604
# 1     3.251925
# 2     3.009868
# 3     1.703533
# 4     1.702201
#         ...
# 95    2.079686
# 96    2.506915
# 97    2.525658
# 98    1.689184
# 99    2.129374
# Name: Energy Consumption (kWh), Length: 100, dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Reload the appliance energy data to ensure correct DataFrame context
df=pd.read_csv("/content/appliance_energy.csv")

# Independent variable
X=df[['Temperature (°C)']]
# Dependent variable
Y=df['Energy Consumption (kWh)']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Create a linear Regression Model
model=LinearRegression()
#Train the model
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Make Predictions on the test set
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

#Calculate Mean Squared Error
mse=mean_squared_error(Y_test,y_pred)
print(f"Mean Squaredd Error:{mse}")
#Calculate R-Squared value
r2=r2_score(Y_test,y_pred)
print(f"R-Squared Value:{r2}")
# Out:
# Mean Squaredd Error:0.16342487842925055
# R-Squared Value:0.6119478445218713

# %%
#plot the test data and regreassion line
plt.scatter(X_test,Y_test,color='blue', label='Test Data')
plt.plot(X_test,y_pred,color='red',label='Regression Line')
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.title('Temperature vs Energy Consumption')
plt.legend()
plt.title("Energy Consumption using Simple Liner Regression")
plt.show()

# %%
import joblib
#Ssave the model to a file
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2)
X_ploy_train=poly.fit_transform(X_train)
X_ploy_test=poly.transform(X_test)

# %%
model=LinearRegression()
model.fit(X_ploy_train,Y_train)
# Out:
# LinearRegression()

# %%
df=pd.read_csv("/content/solar_power_output.csv")

# %%
print(df.isnull().sum())
# Out:
# temperature           0
# humidity              0
# solar_irradiance      0
# wind_speed            0
# solar_power_output    0
# dtype: int64

# %%
df=df.dropna()

# %%
#Independent varaible
X=df[['temperature','humidity','solar_irradiance','wind_speed']]
#Dependent varaible
Y=df['solar_power_output']

# %%
print(X,Y)
# Out:
#      temperature   humidity  solar_irradiance  wind_speed
# 0      19.363503  75.852937        266.619636    5.190818
# 1      33.767858  62.887709        587.710853    4.791819
# 2      28.299849  44.762209        885.651252    0.256421
# 3      24.966462  85.103602        759.002398    3.412478
# 4      13.900466  74.778494        825.905033    3.801956
# ..           ...        ...               ...         ...
# 495    18.833806  27.326566        701.391519    6.569552
# 496    24.591403  93.385086        657.541311    9.566146
# 497    11.943366  30.945490        517.144639    0.689580
# 498    34.359870  96.018988        441.807202    0.570547
# 499    34.655269  55.680462        877.000285    2.821871
#
# [500 rows x 4 columns] 0      128.101772
# 1      290.911789
# 2      442.336390
# 3      380.261988
# 4      415.931953
#           ...
# 495    352.480220
# 496    326.834297
# 497    259.133251
# 498    223.778239
# 499    435.410369
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
model=LinearRegression()
#Train the model
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

#Calculate Mean Squared Error
mse=mean_squared_error(Y_test,y_pred)
print(f"Mean Squaredd Error:{mse}")
#Calculate R-Squared value
r2=r2_score(Y_test,y_pred)
print(f"R-Squared Value:{r2}")
# Out:
# Mean Squaredd Error:26.129583275365476
# R-Squared Value:0.9986209367162825
